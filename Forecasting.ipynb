# %% [markdown]
# <a href="https://colab.research.google.com/github/Srinivasragani/Forecasting-Weather-Dataset/blob/main/Forecasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_html('/content/DailyWiseMarketArrivals.html')
df
# Out:
# [                                      0
#  0  DATE WISE MARKET ARRIVALS AND PRICES,
#            0  ...                                                  3
#  0    Crop :  ...  All  2021  2020  2019  2018  2017  2016  2015 ...
#  1  Market :  ...  All  January  February  March  April  May  Jun...
#  2       NaN  ...                                                NaN
#
#  [3 rows x 4 columns],
#                                                   0
#  0  DATE WISE MARKET ARRIVALS AND PRICES FOR POTATO,
#               Date     Market  ...  Price Maximum (Rs/q) Modal Price (Rs/q)
#  0     01/Jan/2005  BANGALORE  ...                   580                510
#  1     03/Jan/2005  BANGALORE  ...                   560                500
#  2     05/Jan/2005  BANGALORE  ...                   560                500
#  3     06/Jan/2005  BANGALORE  ...                   550                500
#  4     07/Jan/2005  BANGALORE  ...                   460                425
# ...

# %%
type(df)
# Out:
# list

# %%
df=pd.read_html('/content/DailyWiseMarketArrivals.html')[-1]
df
# Out:
#              Date     Market  ...  Price Maximum (Rs/q) Modal Price (Rs/q)
# 0     01/Jan/2005  BANGALORE  ...                   580                510
# 1     03/Jan/2005  BANGALORE  ...                   560                500
# 2     05/Jan/2005  BANGALORE  ...                   560                500
# 3     06/Jan/2005  BANGALORE  ...                   550                500
# 4     07/Jan/2005  BANGALORE  ...                   460                425
# ...           ...        ...  ...                   ...                ...
# 4145  06/Nov/2021  BANGALORE  ...                  1400               1300
# 4146  08/Nov/2021  BANGALORE  ...                  1200               1100
# 4147  11/Nov/2021  BANGALORE  ...                  1000                950
# 4148  12/Nov/2021  BANGALORE  ...                  1000                900
# 4149          NaN      Total  ...             1402(Avg)          1184(Avg)
#
# [4150 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4150 entries, 0 to 4149
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  4149 non-null   object
#  1   Market                4150 non-null   object
#  2   Arrival(q)            4150 non-null   int64
#  3   Price Minimum (Rs/q)  4150 non-null   object
#  4   Price Maximum (Rs/q)  4150 non-null   object
#  5   Modal Price (Rs/q)    4150 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 194.7+ KB

# %%
df.dropna()
# Out:
#              Date     Market  ...  Price Maximum (Rs/q) Modal Price (Rs/q)
# 0     01/Jan/2005  BANGALORE  ...                   580                510
# 1     03/Jan/2005  BANGALORE  ...                   560                500
# 2     05/Jan/2005  BANGALORE  ...                   560                500
# 3     06/Jan/2005  BANGALORE  ...                   550                500
# 4     07/Jan/2005  BANGALORE  ...                   460                425
# ...           ...        ...  ...                   ...                ...
# 4144  02/Nov/2021  BANGALORE  ...                  1400               1300
# 4145  06/Nov/2021  BANGALORE  ...                  1400               1300
# 4146  08/Nov/2021  BANGALORE  ...                  1200               1100
# 4147  11/Nov/2021  BANGALORE  ...                  1000                950
# 4148  12/Nov/2021  BANGALORE  ...                  1000                900
#
# [4149 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Date                    1
# Market                  0
# Arrival(q)              0
# Price Minimum (Rs/q)    0
# Price Maximum (Rs/q)    0
# Modal Price (Rs/q)      0
# dtype: int64

# %%
df=df.dropna()
df
# Out:
#              Date     Market  ...  Price Maximum (Rs/q) Modal Price (Rs/q)
# 0     01/Jan/2005  BANGALORE  ...                   580                510
# 1     03/Jan/2005  BANGALORE  ...                   560                500
# 2     05/Jan/2005  BANGALORE  ...                   560                500
# 3     06/Jan/2005  BANGALORE  ...                   550                500
# 4     07/Jan/2005  BANGALORE  ...                   460                425
# ...           ...        ...  ...                   ...                ...
# 4144  02/Nov/2021  BANGALORE  ...                  1400               1300
# 4145  06/Nov/2021  BANGALORE  ...                  1400               1300
# 4146  08/Nov/2021  BANGALORE  ...                  1200               1100
# 4147  11/Nov/2021  BANGALORE  ...                  1000                950
# 4148  12/Nov/2021  BANGALORE  ...                  1000                900
#
# [4149 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Date                    0
# Market                  0
# Arrival(q)              0
# Price Minimum (Rs/q)    0
# Price Maximum (Rs/q)    0
# Modal Price (Rs/q)      0
# dtype: int64

# %%
df.rename(columns = {'Date':'ds','Modal Price (Rs/q)':'y'}, inplace = True)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                ds     Market  ...  Price Maximum (Rs/q)     y
# 0     01/Jan/2005  BANGALORE  ...                   580   510
# 1     03/Jan/2005  BANGALORE  ...                   560   500
# 2     05/Jan/2005  BANGALORE  ...                   560   500
# 3     06/Jan/2005  BANGALORE  ...                   550   500
# 4     07/Jan/2005  BANGALORE  ...                   460   425
# ...           ...        ...  ...                   ...   ...
# 4144  02/Nov/2021  BANGALORE  ...                  1400  1300
# 4145  06/Nov/2021  BANGALORE  ...                  1400  1300
# 4146  08/Nov/2021  BANGALORE  ...                  1200  1100
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4149 entries, 0 to 4148
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ds                    4149 non-null   object
#  1   Market                4149 non-null   object
#  2   Arrival(q)            4149 non-null   int64
#  3   Price Minimum (Rs/q)  4149 non-null   object
#  4   Price Maximum (Rs/q)  4149 non-null   object
#  5   y                     4149 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 226.9+ KB

# %%
df_new = df[['ds','y']] #create a new dataframe of only these two columns
df_new
# Out:
#                ds     y
# 0     01/Jan/2005   510
# 1     03/Jan/2005   500
# 2     05/Jan/2005   500
# 3     06/Jan/2005   500
# 4     07/Jan/2005   425
# ...           ...   ...
# 4144  02/Nov/2021  1300
# 4145  06/Nov/2021  1300
# 4146  08/Nov/2021  1100
# 4147  11/Nov/2021   950
# 4148  12/Nov/2021   900
#
# [4149 rows x 2 columns]

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4149 entries, 0 to 4148
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      4149 non-null   object
#  1   y       4149 non-null   object
# dtypes: object(2)
# memory usage: 97.2+ KB

# %%
df_new['ds']=pd.to_datetime(df_new['ds'])
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4149 entries, 0 to 4148
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      4149 non-null   datetime64[ns]
#  1   y       4149 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 97.2+ KB
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_new
# Out:
#              ds     y
# 0    2005-01-01   510
# 1    2005-01-03   500
# 2    2005-01-05   500
# 3    2005-01-06   500
# 4    2005-01-07   425
# ...         ...   ...
# 4144 2021-11-02  1300
# 4145 2021-11-06  1300
# 4146 2021-11-08  1100
# 4147 2021-11-11   950
# 4148 2021-11-12   900
#
# [4149 rows x 2 columns]

# %%
df_new['y'] = df_new['y'].astype(int) #object to int datatype conversion
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4149 entries, 0 to 4148
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      4149 non-null   datetime64[ns]
#  1   y       4149 non-null   int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 97.2 KB
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_new
# Out:
#              ds     y
# 0    2005-01-01   510
# 1    2005-01-03   500
# 2    2005-01-05   500
# 3    2005-01-06   500
# 4    2005-01-07   425
# ...         ...   ...
# 4144 2021-11-02  1300
# 4145 2021-11-06  1300
# 4146 2021-11-08  1100
# 4147 2021-11-11   950
# 4148 2021-11-12   900
#
# [4149 rows x 2 columns]

# %%
import matplotlib.pyplot as plt 
plt.figure(figsize = (20,10)) #increase fiigure size 
plt.scatter(df_new['ds'],df_new['y']) # values from the dataset 
plt.show()

# %%
import numpy as np
df_new['y']=np.where(df_new['y']>2700,np.nan,df_new['y'])
df_new
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#              ds       y
# 0    2005-01-01   510.0
# 1    2005-01-03   500.0
# 2    2005-01-05   500.0
# 3    2005-01-06   500.0
# 4    2005-01-07   425.0
# ...         ...     ...
# 4144 2021-11-02  1300.0
# 4145 2021-11-06  1300.0
# 4146 2021-11-08  1100.0
# 4147 2021-11-11   950.0
# 4148 2021-11-12   900.0
#
# [4149 rows x 2 columns]

# %%
df_new.isnull().sum()
# Out:
# ds     0
# y     11
# dtype: int64

# %%
import matplotlib.pyplot as plt 
plt.figure(figsize = (20,10)) #increase fiigure size 
plt.scatter(df_new['ds'],df_new['y']) # values from the dataset 
plt.show()

# %%
import fbprophet
op=fbprophet.Prophet()
op=fbprophet.Prophet(changepoint_prior_scale=1)
op.fit(df_new)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast=op.make_future_dataframe(periods=365,freq='D')

# %%
forecast=op.predict(forecast)

# %%
forecast
# Out:
#              ds        trend  ...  multiplicative_terms_upper         yhat
# 0    2005-01-01   531.674710  ...                         0.0   602.533091
# 1    2005-01-03   533.515739  ...                         0.0   605.753679
# 2    2005-01-05   535.356768  ...                         0.0   610.298823
# 3    2005-01-06   536.277282  ...                         0.0   607.925219
# 4    2005-01-07   537.197797  ...                         0.0   600.861011
# ...         ...          ...  ...                         ...          ...
# 4503 2022-11-08  1866.882164  ...                         0.0  2031.734406
# 4504 2022-11-09  1867.256528  ...                         0.0  2037.371097
# 4505 2022-11-10  1867.630892  ...                         0.0  2040.318104
# 4506 2022-11-11  1868.005257  ...                         0.0  2037.892278
# 4507 2022-11-12  1868.379621  ...                         0.0  2038.786013
#
# [4508 rows x 19 columns]

# %%
plt.figure(figsize=(25,20))
op.plot(forecast,xlabel='Price',ylabel='Date')
